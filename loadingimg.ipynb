# %% [markdown]
# <a href="https://colab.research.google.com/github/sin-h43/Unsupervised-2D-Image-Registration-PoC/blob/main/loadingimg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread("/content/cat2.jpeg", cv2.IMREAD_GRAYSCALE)

print(img.shape)

plt.imshow(img, cmap='gray')
plt.title("Grayscale Image")
plt.axis('off')
plt.show()
# Out:
# (251, 201)
